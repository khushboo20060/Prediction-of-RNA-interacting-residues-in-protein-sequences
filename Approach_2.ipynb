# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import VotingClassifier
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from imblearn.under_sampling import NearMiss
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
import statistics
from collections import Counter
from imblearn.under_sampling import NearMiss
import joblib
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import matthews_corrcoef
from sklearn import svm
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/IP_Raghavasir/dataset_original/RNA_Train.csv")

# %%
df2 = pd.read_csv("/content/drive/MyDrive/IP_Raghavasir/dataset_original/test (1).csv")

# %%
AA =['A','C','D','E','F','G','H','I','K','L','M','N','O','P','Q','R','S','T','U','V','W','Y','X']
posDataset = pd.DataFrame(columns=AA)
for i in range(0,df.shape[0]):
  word=df.loc[i]['Sequence']
  posDict ={'A':0,'C':0,'D':0,'E':0,'F':0,'G':0,'H':0,'I':0,'K':0,'L':0,'M':0,'N':0,'O':0,'P':0,'Q':0,'R':0,'S':0,'T':0,'U':0,'V':0,'W':0,'Y':0,'X':0}
  for j in range(0,len(df.loc[i]['Sequence'])):
    posDict[word[j]] = j
  posDataset = posDataset.append(posDict, ignore_index=True)
  print(i)
# Out:
# Streaming output truncated to the last 5000 lines.
# 227778
# 227779
# 227780
# 227781
# 227782
# 227783
# 227784
# 227785
# 227786
# 227787
# 227788
# 227789
# 227790
# 227791
# 227792
# 227793
# 227794
# 227795
# 227796
# 227797
# 227798
# 227799
# 227800
# 227801
# 227802
# 227803
# 227804
# 227805
# 227806
# 227807
# 227808
# 227809
# 227810
# 227811
# 227812
# 227813
# 227814
# 227815
# 227816
# 227817
# 227818
# 227819
# 227820
# 227821
# 227822
# 227823
# 227824
# 227825
# 227826
# 227827
# 227828
# 227829
# 227830
# 227831
# 227832
# 227833
# 227834
# 227835
# 227836
# 227837
# 227838
# 227839
# 227840
# 227841
# 227842
# 227843
# 227844
# 227845
# 227846
# 227847
# 227848
# 227849
# 227850
# 227851
# 227852
# 227853
# 227854
# 227855
# 227856
# 227857
# 227858
# 227859
# 227860
# 227861
# 227862
# 227863
# 227864
# 227865
# 227866
# 227867
# 227868
# 227869
# 227870
# 227871
# 227872
# 227873
# 227874
# 227875
# 227876
# 227877
# 227878
# 227879
# 227880
# 227881
# 227882
# ...

# %%
posDataset.to_csv('/content/drive/MyDrive/IP_Raghavasir/dataset_created/posDatasetTrain.csv')

# %%
AA =['A','C','D','E','F','G','H','I','K','L','M','N','O','P','Q','R','S','T','U','V','W','Y','X']
posDatasetTest = pd.DataFrame(columns=AA)
for i in range(0,df2.shape[0]):
  word=df2.loc[i]['Sequence']
  posDicttest ={'A':0,'C':0,'D':0,'E':0,'F':0,'G':0,'H':0,'I':0,'K':0,'L':0,'M':0,'N':0,'O':0,'P':0,'Q':0,'R':0,'S':0,'T':0,'U':0,'V':0,'W':0,'Y':0,'X':0}
  for j in range(0,len(df2.loc[i]['Sequence'])):
    posDicttest[word[j]] = j
  posDatasetTest = posDatasetTest.append(posDicttest, ignore_index=True)
  print(i)

# %%
posDatasetTest.to_csv('/content/drive/MyDrive/IP_Raghavasir/dataset_created/posDataset.csv')

# %%
dataset = pd.read_csv("/content/drive/MyDrive/IP_Raghavasir/dataset_created/posDatasetTrain.csv",index_col = False)

# %%
dataset

# %%
datasetTest = pd.read_csv("/content/drive/MyDrive/IP_Raghavasir/dataset_created/posDataset.csv",index_col = False)

# %%
datasetTest

# %%
countfeature = pd.read_csv("/content/drive/MyDrive/IP_Raghavasir/dataset_created/OneHot.csv")

# %%
countfeature

# %%
countfeaturetest = pd.read_csv("/content/drive/MyDrive/IP_Raghavasir/dataset_created/oneHotTest.csv")

# %%
countfeature

# %%
datasetTest = datasetTest.drop(["Unnamed: 0","X"],axis=1)

# %%
datasetTest

# %%
countfeaturetest

# %%
dataset

# %%
original = pd.read_csv("/content/drive/MyDrive/IP_Raghavasir/dataset_original/RNA_Train.csv")

# %%
test = pd.read_csv("/content/drive/MyDrive/IP_Raghavasir/dataset_created/posDataset.csv")

# %%
dataset['label'] = original['label']

# %%
dataset = dataset.drop("X",axis=1)

# %%
dataset = dataset.drop("Unnamed: 0",axis=1)

# %%
dataset

# %%
allfeature = pd.concat([dataset, countfeature], axis=1)

# %%
allfeature

# %%
allfeatureTest = pd.concat([datasetTest, countfeaturetest], axis=1)

# %%
allfeatureTest

# %%
allfeature.to_csv("/content/drive/MyDrive/IP_Raghavasir/dataset_created/allfeature.csv")

# %%
allfeatureTest.to_csv("/content/drive/MyDrive/IP_Raghavasir/dataset_created/allfeatureTest.csv")

# %%
test = test.drop(["X","Unnamed: 0"],axis=1)

# %%
test

# %%
dataset.iloc[:, :-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset.iloc[:, :-1], dataset['label'],test_size = 0.25, random_state = 0)

# %%
clf = RandomForestClassifier(n_estimators=500)
clf.fit(X_train, y_train)

# %%
predicted = clf.predict(X_test)

# %%
matthews_corrcoef(y_test, predicted)

# %%
allfeature.iloc[:, :-1]

# %%
clf = RandomForestClassifier(n_estimators=500)
clf.fit(allfeature.iloc[:, :-1],allfeature['label'])

# %%
testpredicted = clf.predict(allfeatureTest)

# %%
test = pd.read_csv("/content/drive/MyDrive/IP_Raghavasir/dataset_original/test.csv")

# %%
oversample = RandomOverSampler(sampling_strategy='minority')

# %%
X_over, y_over = oversample.fit_resample(allfeature.iloc[:, :-1],allfeature['label'])

# %%
X_over.shape , y_over.shape

# %%
model_GB = GradientBoostingClassifier(n_estimators=500, max_depth=6)
model_GB.fit(X_over, y_over)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_gb.py:1454: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=6,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=500,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=None, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
y_pred = model_GB.predict(test)

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_over, y_over)

# %%
predicted = knn.predict(test )

# %% [markdown]
# ### Undersampling

# %%
under = RandomUnderSampler()

# %%
X, y = under.fit_resample(allfeature.iloc[:, :-1],allfeature['label'])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
X.shape , y.shape
# Out:
# ((77798, 45), (77798,))

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X , y)

# %%
predicted = knn.predict(test)

# %%
clf = RandomForestClassifier(n_estimators=500)
clf.fit(X, y)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=500,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
predicted = clf.predict(test)
